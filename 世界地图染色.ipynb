# %%
from mpl_toolkits.basemap import Basemap

# %%
import matplotlib.pyplot as plt

# %%
# map = Basemap(projection="ortho", lat_0=0, lon_0=0)  # projection 参数设置投影模式 lat_0  lon_0 经纬度

# map = Basemap(projection='cyl')

map.drawmapboundary(fill_color='aqua')  # 地球涂蓝色
map.fillcontinents(color='coral', lake_color='aqua')  # 大陆 黄色 水 蓝色
map.drawcoastlines()
plt.show()
