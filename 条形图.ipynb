# %%
import plotly.plotly as py

# %%
import plotly.graph_objs as go

# %%
py.sign_in("cherrymonthes", "jwmxadkZ3tI8UDD7pZoU")  # 可视化图像保存到网站上

# %%
trace = go.Bar(x=[2, 4, 6], y=[10, 12, 15], )   # 柱状图 变量名为柱状图的名称

# %%
data = [trace, trace, trace]

# %%
layout = go.Layout(title="simple plot", width=800, height=640)

# %%
fig = go.Figure(data=data, layout=layout)  # 布局控制器

# %%
py.image.save_as(fig, filename="test.png")  # 打印图片

# %%
from IPython.display import Image,TextDisplayObject

# %%
Image("test.png")
